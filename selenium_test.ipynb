# %%
from selenium import webdriver
from time import sleep

# %%
driver = webdriver.Chrome(
executable_path ="../python/chromedriver.exe"
)
url = "https://www.instagram.com/witheverland/"

driver.get(url)
sleep(10)
pageString = driver.page_source
print(pageString)
driver.close()
# Out:
# <html lang="ko" class="js not-logged-in client-root js-focus-visible sDN5V"><head>
#         <meta charset="utf-8">
#         <meta http-equiv="X-UA-Compatible" content="IE=edge">
#
#         <title>에버랜드(withEverland)(@witheverland) • Instagram 사진 및 동영상</title>
#
#
#         <meta name="robots" content="noimageindex, noarchive">
#         <meta name="apple-mobile-web-app-status-bar-style" content="default">
#         <meta name="mobile-web-app-capable" content="yes">
#         <meta name="theme-color" content="#ffffff">
#         <meta id="viewport" name="viewport" content="width=device-width, initial-scale=1, minimum-scale=1, maximum-scale=1, viewport-fit=cover">
#         <link rel="manifest" href="/data/manifest.json">
#
#         <link rel="preload" href="/static/bundles/es6/ConsumerUICommons.css/739b50b97f72.css" as="style" type="text/css" crossorigin="anonymous">
# ...
